# %% [markdown]
# <a href="https://colab.research.google.com/github/vbtsahu/CODSOFT/blob/main/Credit_card_fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
file=pd.read_csv("credit_dataset.csv")

# %%
file.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5     2 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6     4  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7     7 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8     7 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9     9 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
# 5  0.105915  0.253844  0.081080    3.67    0.0
# 6 -0.257237  0.034507  0.005168    4.99    0.0
# 7 -0.051634 -1.206921 -1.085339   40.80    0.0
# 8 -0.384157  0.011747  0.142404   93.20    0.0
# 9  0.094199  0.246219  0.083076    3.68    0.0
#
# [10 rows x 31 columns]

# %%
file.describe()
# Out:
#                Time           V1           V2           V3           V4  \
# count   8766.000000  8766.000000  8766.000000  8766.000000  8766.000000
# mean    4894.080424    -0.262707     0.276243     0.903769     0.217214
# std     3659.865012     1.521932     1.316532     1.101483     1.436364
# min        0.000000   -27.670569   -34.607649   -12.389545    -4.657545
# 25%     1711.500000    -1.028743    -0.217634     0.398443    -0.660507
# 50%     3765.000000    -0.394821     0.306407     0.936989     0.206569
# 75%     7991.000000     1.144834     0.914845     1.593165     1.106434
# max    11932.000000     1.960497     8.261750     4.101716    10.463020
#
#                 V5           V6           V7           V8           V9  ...  \
# count  8766.000000  8766.000000  8766.000000  8766.000000  8766.000000  ...
# mean     -0.034510     0.128270    -0.046677    -0.072294     0.728188  ...
# std       1.205127     1.326243     1.083787     1.289670     1.159165  ...
# min     -32.092129   -23.496714   -26.548144   -23.632502    -6.272790  ...
# 25%      -0.640217    -0.652708    -0.522498    -0.198339    -0.020013  ...
# 50%      -0.131425    -0.170421    -0.021202     0.006406     0.697720  ...
# 75%       0.384167     0.504494     0.503021     0.280994     1.436676  ...
# max      34.099309    21.393069    34.303177     3.877662    10.392889  ...
#
#                V21          V22          V23          V24          V25  \
# count  8766.000000  8766.000000  8766.000000  8766.000000  8766.000000
# mean     -0.055446    -0.158052    -0.037962     0.025195     0.089314
# std       0.928883     0.641624     0.490750     0.597736     0.429696
# min     -11.468435    -8.527145   -15.144340    -2.512377    -2.577363
# 25%      -0.268549    -0.556611    -0.180358    -0.338479    -0.158342
# 50%      -0.126627    -0.149331    -0.049011     0.085047     0.123624
# 75%       0.038298     0.245290     0.081211     0.419062     0.360417
# max      22.588989     4.534454    13.876221     3.200201     5.525093
#
#                V26          V27          V28       Amount        Class
# count  8766.000000  8766.000000  8766.000000  8765.000000  8765.000000
# mean      0.074311     0.011304     0.002271    63.788774     0.003423
# std       0.548979     0.407724     0.275457   189.989538     0.058407
# min      -1.338556    -7.976100    -3.509250     0.000000     0.000000
# 25%      -0.341189    -0.080466    -0.016702     5.000000     0.000000
# 50%       0.025788    -0.000373     0.017039    15.950000     0.000000
# 75%       0.400858     0.132495     0.078694    52.500000     0.000000
# max       3.517346     8.254376     4.860769  7712.430000     1.000000
#
# [8 rows x 31 columns]

# %%
file.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    1
# Class     1
# dtype: int64

# %%
file['Class'].value_counts()
# Out:
# 0.0    8735
# 1.0      30
# Name: Class, dtype: int64

# %%
normal=file[file.Class==0]

# %%
fraud=file[file.Class==1]

# %%
print(normal.shape)
# Out:
# (8735, 31)

# %%
print(normal.shape)
# Out:
# (8735, 31)

# %%
normal.Amount.describe()
# Out:
# count    8735.000000
# mean       63.703021
# std       189.290575
# min         0.000000
# 25%         5.000000
# 50%        15.950000
# 75%        52.520000
# max      7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      30.000000
# mean       88.757000
# std       341.372542
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
file.groupby('Class').mean()
# Out:
#               Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    4882.544820 -0.259336  0.266048  0.925581  0.200324 -0.032140
# 1.0    8018.266667 -1.166570  3.286696 -5.482274  5.085269 -0.719672
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.135860 -0.037305 -0.075399  0.737494  ...  0.034879 -0.057467
# 1.0   -2.080676 -2.767707  0.807816 -1.990289  ...  0.394607  0.519188
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.157840 -0.037685  0.026254  0.089180  0.073536  0.009300  0.001242
# 1.0   -0.241668 -0.129442 -0.284319  0.116275  0.307045  0.589117  0.306852
#
#           Amount
# Class
# 0.0    63.703021
# 1.0    88.757000
#
# [2 rows x 30 columns]

# %%
normal_sample=normal.sample(n=492)

# %%
new_file=pd.concat([normal_sample,fraud],axis=0)

# %%
new_file.head(10)
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 1951   1504 -1.026082  1.344535  1.364817 -0.707748 -0.064382 -0.720407
# 5168   4917  0.945910 -0.832504  0.880598 -0.637727 -0.978465  0.507006
# 6577   8006 -0.491204  1.112339  1.894571  0.248902 -0.099383 -0.680094
# 6247   7319  1.316476 -0.762287  1.147227 -0.537621 -1.180770  0.514797
# 6905   8887 -7.607299 -9.305303  0.349755  3.717203  6.639899 -5.697611
# 4773   4237  1.106475  0.092237  1.415262  1.489986 -0.636905  0.341660
# 7308   9797 -0.754848  2.017183  1.607419  2.985311 -0.109057 -0.127915
# 7365   9914 -1.624191  1.385022  1.027190  0.454470 -0.138468 -0.242050
# 8282  11072 -0.500321  0.573189  2.088263 -0.914466  0.213783 -0.539376
# 1587   1237 -0.234716  0.116213  1.628243 -0.463817 -1.134419 -0.962314
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 1951  0.558181 -0.882456  0.108784  ...  0.550390 -0.580493  0.022288
# 5168 -0.970658  0.388224  3.095443  ...  0.124262  0.623589 -0.123970
# 6577  0.550890 -0.035107  0.871683  ... -0.316369 -0.581338  0.093204
# 6247 -1.482598  0.269653  1.035685  ...  0.202063  0.901793 -0.099016
# 6905 -4.965321  0.947028  1.137335  ...  0.715863 -1.312283  0.196384
# 4773 -0.660119  0.093178  2.025564  ... -0.171946  0.032333  0.022263
# 7308  0.183168  0.249332 -0.426100  ... -0.102655 -0.042951 -0.031451
# 7365 -0.042756  0.403260  0.809935  ...  0.040618  0.534194  0.148002
# 8282  0.552339 -0.307908  1.331429  ... -0.058868  0.169257 -0.277703
# 1587  0.454757 -0.285269 -1.772633  ... -0.263602 -0.380436  0.325282
#
#            V24       V25       V26       V27       V28  Amount  Class
# 1951  0.425627 -0.114143  0.300114  0.451212  0.251131    5.00    0.0
# 5168 -0.336001  0.305006 -0.416397  0.060094  0.020075   91.66    0.0
# 6577  0.521463 -0.365452  0.029747  0.253847  0.116323    5.99    0.0
# 6247 -0.320577  0.359021 -0.049807  0.033547 -0.000639    0.00    0.0
# 6905  0.392936 -1.346621 -0.055579  0.237003 -1.426355    0.89    0.0
# 4773  0.050277  0.350503 -0.421783  0.067878  0.031229   12.99    0.0
# 7308  0.358072 -0.329145  0.057368  0.113989  0.141759    2.97    0.0
# 7365  0.201192 -0.225176  0.421529 -0.013782  0.130956    2.42    0.0
# 8282 -0.110919 -0.118596  0.880121 -0.190316 -0.136133   15.95    0.0
# 1587  0.952910 -0.809614  0.919784  0.081575  0.163116   93.00    0.0
#
# [10 rows x 31 columns]

# %%
new_file['Class'].value_counts()
# Out:
# 0.0    492
# 1.0     30
# Name: Class, dtype: int64

# %%
new_file.groupby('Class').mean()
# Out:
#               Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    4848.347561 -0.290693  0.291382  0.885130  0.247846  0.021045
# 1.0    8018.266667 -1.166570  3.286696 -5.482274  5.085269 -0.719672
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.124778 -0.091148 -0.049931  0.661208  ...  0.026715 -0.079303
# 1.0   -2.080676 -2.767707  0.807816 -1.990289  ...  0.394607  0.519188
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.175850 -0.028846  0.037261  0.072105  0.113584  0.029030  0.006653
# 1.0   -0.241668 -0.129442 -0.284319  0.116275  0.307045  0.589117  0.306852
#
#           Amount
# Class
# 0.0    53.241199
# 1.0    88.757000
#
# [2 rows x 30 columns]

# %%
X=new_file.drop(columns='Class',axis=1)

# %%
Y=new_file['Class']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
model=LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction=model.predict(X_train)

# %%
training_data_acuracy=accuracy_score(X_train_prediction,Y_train)*100

# %%
print(f"Training Data Accuracy: {training_data_acuracy}%")
# Out:
# Training Data Accuracy: 99.76019184652279%

# %%
X_test_prediction=model.predict(X_test)

# %%
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)*100

# %%
print(f"Test Data Accuracy: {test_data_accuracy}%")
# Out:
# Test Data Accuracy: 99.04761904761905%
